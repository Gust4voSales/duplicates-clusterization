# %% [markdown]
# <a href="https://colab.research.google.com/github/Gust4voSales/duplicates-identification/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LOAD

# %%
# !pip install Levenshtein phonex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Levenshtein
#   Downloading Levenshtein-0.20.9-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 KB 13.2 MB/s eta 0:00:00
# Collecting phonex
#   Downloading phonex-0.0.2-py3-none-any.whl (3.9 kB)
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 72.8 MB/s eta 0:00:00
# Installing collected packages: phonex, rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.20.9 phonex-0.0.2 rapidfuzz-2.13.7

# %%
import numpy as np
import pandas as pd

filename = 'Music_Brainz_20K.csv'

def get_database(filename=filename):
  df = pd.read_csv(filename)
  return df

# %% [markdown]
# # CLEAN DATABASE

# %% [markdown]
# ## Clean functions

# %%
# clean strings
import re 

STRING_COLUMNS = ['title','artist','album']

# replace NaN with '' on STRING_COLUMNS
def clean_strings(df):
  df[STRING_COLUMNS] = df[STRING_COLUMNS].replace(np.nan, '')
  return df

# We don't remove non alphanumerics now, because we wouldn't be able to 
# undestand anything when we analyze the data. So we call this function 
# when we calculate the strings_distance
def remove_non_alphanum(string: str):
  return re.sub(r'\W+', '', string)

# %%
# clean years

def convert_year(year):
    if len(year) == 2:
        if int(year) < 50:
            return int('20' + year)
        else:
            return int('19' + year)
    elif len(year) == 4:
      return int(year)
    
    return 0

def clean_years(df):
  # parse years to the same format
  df['year'] = df['year'].replace(np.nan, '0')

  # remove all non-numerics from year column (example: '02 ==> 02)
  df['year'] = df['year'].str.replace(r'\D+', '', regex=True)

  df['year'] = df['year'].apply(lambda x: convert_year(x))

  return df

# %%
# remove unnecessary columns

UNUSED_COLUMNS = ['CTID', 'id',	'SourceID', 'length', 'language']
def remove_unused_columns(df):
  return df.drop(columns = UNUSED_COLUMNS)

# %% [markdown]
# ## Clean everything

# %%
# a single function that calls all the above clean functions
def clean_db(df):
  df = remove_unused_columns(df)
  df = clean_strings(df)
  df = clean_years(df)
  return df

# %% [markdown]
# # DISTANCES FUNCTIONS

# %% [markdown]
# ## Individual Attributes distances functions

# %%
# STRING distance (title, album and artist...)
import Levenshtein as lev

def string_distance(string1: str, string2: str):
  x = remove_non_alphanum(string1).lower()
  y = remove_non_alphanum(string2).lower()
  
  dist = lev.distance(x, y) 

  max_len = max(len(x), len(y))
  if (max_len == 0):
    return 0
  normalized = (max_len-dist) / max_len 
  normalized_dist = 1-normalized
  return normalized_dist

# %%
# year distance
def year_distance(year1: int, year2: int):
    if (year1==year2): 
      return 0
    return 1

# %%
# number_track distance
def number_track_distance(number_t1, number_t2):
  if str(number_t1).isnumeric() and str(number_t2).isnumeric():
    number_t1 = int(number_t1)
    number_t2 = int(number_t2)

  if(number_t1 == number_t2):
    return 0
  return 1

# %% [markdown]
# ## Custom Distance function

# %%
# custom distance function

title_w = 1.2
album_w = 1
artist_w = 1
number_track_w = .8
year_w = .5

def distance(item, rows):
  distances = []
  
  for _, row in rows.iterrows():
    w_sum = 0

    title_dist = 0
    album_dist = 0
    artist_dist = 0
    year_dist = 0
    number_track_dist = 0
    
    if (item['title'] and row['title']):
      title_dist = string_distance(item['title'], row['title'])
      w_sum += title_w

    if (item['album'] and row['album']):
      album_dist = string_distance(item['album'], row['album'])
      w_sum += album_w

    if (item['artist'] and row['artist']):
      artist_dist = string_distance(item['artist'], row['artist'])
      w_sum += artist_w

    if (item['year']>0 and row['year']>0):
      year_dist = year_distance(item['year'], row['year'])
      w_sum += year_w

    if (str(item['number']).isnumeric() and str(row['number']).isnumeric()):
      if (int(item['number'])>0 and int(row['number'])>0):
        number_track_dist = number_track_distance(item['number'], row['number'])
        w_sum += number_track_w

    if (w_sum == 0): # don't divide by 0, it could happen
      distances.append(1)
    else:
      dist = ( (title_dist*title_w) + (album_dist*album_w) + (artist_dist*artist_w)
      + (number_track_dist*number_track_w) + (year_dist*year_w) ) / w_sum
      distances.append(dist)

  return np.array(distances)

# %% [markdown]
# # BLOCKING

# %%
# Function that adds a title_phonex column to the database
from phonex import phonex

TITLE_PHONEX_COLUMN_NAME = 'title_phonex'

def calculate_phonex(string):
  string = ''.join(filter(str.isalpha, string))
  return phonex(string)

def add_title_phonex_column(df, column_name=TITLE_PHONEX_COLUMN_NAME):
  df[TITLE_PHONEX_COLUMN_NAME] = df['title'].apply(calculate_phonex)
  return df

# %%
class Blocker:
  def __init__(self, df, MAX_BLOCK_SIZE):
    self.df = df
    self.blocks = []
    self.MAX_BLOCK_SIZE = MAX_BLOCK_SIZE

  def add_title_phonex(self):
    df = add_title_phonex_column(self.df, TITLE_PHONEX_COLUMN_NAME)
    df = df.sort_values(TITLE_PHONEX_COLUMN_NAME, ascending=True) # sort by title_phonex 

    self.df = df

  # def divide_base_into_blocks(self,start_range, end_range):
  def divide_base_into_blocks(self):
    num_blocks = 0
    block_size = self.MAX_BLOCK_SIZE
    if(len(self.df) % block_size==0):
      num_blocks = len(self.df) // block_size
    else:
      num_blocks = len(self.df) // block_size + 1

    # divide the dataframe into blocks of block_size rows each
    self.blocks = [self.df[i:i+block_size] for i in range(0, num_blocks*block_size, block_size)]
        
  def get_blocks(self):
    return self.blocks


def generate_blocks(df, MAX_BLOCK_SIZE=1000):
  b = Blocker(df, MAX_BLOCK_SIZE)
  b.add_title_phonex()
  b.divide_base_into_blocks()
  blocks = b.get_blocks()
  
  return blocks

# %% [markdown]
# # CLUSTERING

# %%
# helper function that get an array of TIDs and returns the items rows 
def get_items_by_TID(df, TIDs):
  items = []

  for TID in TIDs:
    item = df.loc[df['TID'] == TID]
    items.append(item)
    
  return pd.concat(items,  axis=0)

# %%
# CLUSTER with custom KMEANS

def custom_KMEANS(df, threshold=0.4):
  first_el = df.iloc[0]
  centroids_TIDs = [ first_el['TID'] ] # use first item as the first centroid
  
  # clusters (É um dicionário, a chave do dicionário é o TID do centroide, seu valor é um array de items)
  clusters = {key: [] for key in centroids_TIDs} 

  centroids = get_items_by_TID(df, centroids_TIDs) # getting the centroids rows by their TIDs
  
  for index, el in df.iterrows(): 
    
    dists = distance(el, centroids) # calculating the distance from the current element to the centroids, returns --> [distance_to_1st_cent, distance_to_2nd_cent]
    centroid_index_with_min_dist = np.argmin(dists)# get the index of the centroid with the minimum distance to the current element
    
    if (dists[centroid_index_with_min_dist] < threshold):
      min_centroid_TID = centroids_TIDs[centroid_index_with_min_dist] # get the centroid TID from the index  
      clusters[min_centroid_TID].append(el) # Append the current element to that centroid
    else:
      new_centroid_TID = el['TID']
      centroids_TIDs.append(new_centroid_TID)

      centroids.loc[index] = el # add current element as centroid 
      clusters[new_centroid_TID] = [el] # Append the current element to that centroid
  
  return clusters

# %% [markdown]
# # Evaluating

# %%
def calculate_precision(df, clusters):
  total_precision = 0

  for centroid_TID in list(clusters.keys()):
    doubles_find = 0
    cluster_items_len = len(clusters[centroid_TID])
    
    centroid = clusters[centroid_TID][0]
    centroids_doubles_amount= len(df[df['CID'] == centroid['CID']])

    centroids_items = clusters[centroid_TID]

    for item in clusters[centroid_TID]:
      if(item['CID']==centroid['CID']):
        doubles_find+=1

    cluster_precision = doubles_find/centroids_doubles_amount
    total_precision+= cluster_precision
  
  return (total_precision/len(clusters))*100

# %% [markdown]
# # Testando

# %%
import time 

def avaliate(filename, block_size):
  print(f"--LENDO A BASE: {filename}--")
  df = get_database(filename)
  
  print(f"  Limpando a base...")
  df = clean_db(df)

  print(f"  Tamanho da base: {len(df)}")
  print(f"--Blocando em blocks de {block_size} elementos--")
  blocks = generate_blocks(df, block_size)
  print(f"  Quantidade de blocos: {len(blocks)}")

  clusters=[]

  print("--CLUSTERIZAÇÃO--")
  start_time=time.time()
  for i,block in enumerate(blocks):
    print(' Clusterizando bloco ', i)
    clusters.append(custom_KMEANS(block))
  end_time=time.time()
  print(' >> Tempo de execução da clusterização na base: ',end_time - start_time,'s')

  print("--AVALIAÇÃO--")
  precisions = []
  for i in range(len(clusters)):  
    block_precision = calculate_precision(blocks[i], clusters[i]) 
    base_precision = calculate_precision(df, clusters[i])
    precisions.append([block_precision, base_precision])

  precisions_df = pd.DataFrame(precisions, columns=['Relacao Bloco', 'Relacao Base Toda'])
  for i, precision in enumerate(precisions):
    print(f"  BLOCO {i} (teve {len(clusters[i])} clusters): Precisão em relação ao bloco: {precision[0]} %. -- Precisão em relação a base: {precision[1]} %")
    print()

  print("Relacao Bloco: ",(precisions_df['Relacao Bloco'].sum())/len(blocks),' %')
  print("Relacao Base Toda: ",(precisions_df['Relacao Base Toda'].sum())/len(blocks),' %') 

  print()
  print('------------------------------------------------------------------')
  print()
  return precisions_df

# %%
precisions_df = avaliate(filename='Music_Brainz_200K.csv', block_size=250)
# avaliate(filename='Music_Brainz_200K.csv', block_size=1000)
print('Precisão:')
print(precisions_df)
precisions_df.to_csv('precisao.csv')
# Out:
# --LENDO A BASE: Music_Brainz_200K.csv--
#   Limpando a base...
#   Tamanho da base: 193750
# --Blocando em blocks de 250 elementos--
#   Quantidade de blocos: 775
# --CLUSTERIZAÇÃO--
#  Clusterizando bloco  0
# 250
#  Clusterizando bloco  1
# 250
#  Clusterizando bloco  2
# 250
#  Clusterizando bloco  3
# 250
#  Clusterizando bloco  4
# 250
#  Clusterizando bloco  5
# 250
#  Clusterizando bloco  6
# 250
#  Clusterizando bloco  7
# 250
#  Clusterizando bloco  8
# 250
#  Clusterizando bloco  9
# 250
#  Clusterizando bloco  10
# 250
#  Clusterizando bloco  11
# 250
#  Clusterizando bloco  12
# 250
#  Clusterizando bloco  13
# 250
#  Clusterizando bloco  14
# 250
#  Clusterizando bloco  15
# 250
#  Clusterizando bloco  16
# 250
#  Clusterizando bloco  17
# 250
#  Clusterizando bloco  18
# 250
#  Clusterizando bloco  19
# 250
#  Clusterizando bloco  20
# 250
#  Clusterizando bloco  21
# 250
#  Clusterizando bloco  22
# 250
#  Clusterizando bloco  23
# 250
#  Clusterizando bloco  24
# 250
#  Clusterizando bloco  25
# 250
#  Clusterizando bloco  26
# 250
#  Clusterizando bloco  27
# 250
#  Clusterizando bloco  28
# 250
#  Clusterizando bloco  29
# 250
#  Clusterizando bloco  30
# 250
#  Clusterizando bloco  31
# 250
#  Clusterizando bloco  32
# 250
#  Clusterizando bloco  33
# 250
#  Clusterizando bloco  34
# 250
#  Clusterizando bloco  35
# 250
#  Clusterizando bloco  36
# 250
#  Clusterizando bloco  37
# 250
#  Clusterizando bloco  38
# 250
#  Clusterizando bloco  39
# 250
#  Clusterizando bloco  40
# 250
#  Clusterizando bloco  41
# 250
#  Clusterizando bloco  42
# 250
#  Clusterizando bloco  43
# 250
#  Clusterizando bloco  44
# 250
#  Clusterizando bloco  45
# 250
#  Clusterizando bloco  46
# 250
#  Clusterizando bloco  47
# 250
#  Clusterizando bloco  48
# 250
#  Clusterizando bloco  49
# 250
#  Clusterizando bloco  50
# 250
#  Clusterizando bloco  51
# 250
#  Clusterizando bloco  52
# 250
#  Clusterizando bloco  53
# 250
#  Clusterizando bloco  54
# 250
#  Clusterizando bloco  55
# 250
#  Clusterizando bloco  56
# 250
#  Clusterizando bloco  57
# 250
#  Clusterizando bloco  58
# 250
#  Clusterizando bloco  59
# 250
#  Clusterizando bloco  60
# 250
#  Clusterizando bloco  61
# 250
#  Clusterizando bloco  62
# 250
#  Clusterizando bloco  63
# 250
#  Clusterizando bloco  64
# 250
#  Clusterizando bloco  65
# 250
#  Clusterizando bloco  66
# 250
#  Clusterizando bloco  67
# 250
#  Clusterizando bloco  68
# 250
#  Clusterizando bloco  69
# 250
#  Clusterizando bloco  70
# 250
#  Clusterizando bloco  71
# 250
#  Clusterizando bloco  72
# 250
#  Clusterizando bloco  73
# 250
#  Clusterizando bloco  74
# 250
#  Clusterizando bloco  75
# 250
#  Clusterizando bloco  76
# 250
#  Clusterizando bloco  77
# 250
#  Clusterizando bloco  78
# 250
#  Clusterizando bloco  79
# 250
#  Clusterizando bloco  80
# 250
#  Clusterizando bloco  81
# 250
#  Clusterizando bloco  82
# 250
#  Clusterizando bloco  83
# 250
#  Clusterizando bloco  84
# 250
#  Clusterizando bloco  85
# 250
#  Clusterizando bloco  86
# 250
#  Clusterizando bloco  87
# 250
#  Clusterizando bloco  88
# 250
#  Clusterizando bloco  89
# 250
#  Clusterizando bloco  90
# 250
#  Clusterizando bloco  91
# 250
#  Clusterizando bloco  92
# 250
#  Clusterizando bloco  93
# 250
#  Clusterizando bloco  94
# 250
#  Clusterizando bloco  95
# 250
#  Clusterizando bloco  96
# 250
#  Clusterizando bloco  97
# 250
#  Clusterizando bloco  98
# 250
#  Clusterizando bloco  99
# 250
#  Clusterizando bloco  100
# 250
#  Clusterizando bloco  101
# 250
#  Clusterizando bloco  102
# 250
#  Clusterizando bloco  103
# 250
#  Clusterizando bloco  104
# 250
#  Clusterizando bloco  105
# 250
#  Clusterizando bloco  106
# 250
#  Clusterizando bloco  107
# 250
#  Clusterizando bloco  108
# 250
#  Clusterizando bloco  109
# 250
#  Clusterizando bloco  110
# 250
#  Clusterizando bloco  111
# 250
#  Clusterizando bloco  112
# 250
#  Clusterizando bloco  113
# 250
#  Clusterizando bloco  114
# 250
#  Clusterizando bloco  115
# 250
#  Clusterizando bloco  116
# 250
#  Clusterizando bloco  117
# 250
#  Clusterizando bloco  118
# 250
#  Clusterizando bloco  119
# 250
#  Clusterizando bloco  120
# 250
#  Clusterizando bloco  121
# 250
#  Clusterizando bloco  122
# 250
#  Clusterizando bloco  123
# 250
#  Clusterizando bloco  124
# 250
#  Clusterizando bloco  125
# 250
#  Clusterizando bloco  126
# 250
#  Clusterizando bloco  127
# 250
#  Clusterizando bloco  128
# 250
#  Clusterizando bloco  129
# 250
#  Clusterizando bloco  130
# 250
#  Clusterizando bloco  131
# 250
#  Clusterizando bloco  132
# 250
#  Clusterizando bloco  133
# 250
#  Clusterizando bloco  134
# 250
#  Clusterizando bloco  135
# 250
#  Clusterizando bloco  136
# 250
#  Clusterizando bloco  137
# 250
#  Clusterizando bloco  138
# 250
#  Clusterizando bloco  139
# 250
#  Clusterizando bloco  140
# 250
#  Clusterizando bloco  141
# 250
#  Clusterizando bloco  142
# 250
#  Clusterizando bloco  143
# 250
#  Clusterizando bloco  144
# 250
#  Clusterizando bloco  145
# 250
#  Clusterizando bloco  146
# 250
#  Clusterizando bloco  147
# 250
#  Clusterizando bloco  148
# 250
#  Clusterizando bloco  149
# 250
#  Clusterizando bloco  150
# 250
#  Clusterizando bloco  151
# 250
#  Clusterizando bloco  152
# 250
#  Clusterizando bloco  153
# 250
#  Clusterizando bloco  154
# 250
#  Clusterizando bloco  155
# 250
#  Clusterizando bloco  156
# 250
#  Clusterizando bloco  157
# 250
#  Clusterizando bloco  158
# 250
#  Clusterizando bloco  159
# 250
#  Clusterizando bloco  160
# 250
#  Clusterizando bloco  161
# 250
#  Clusterizando bloco  162
# 250
#  Clusterizando bloco  163
# 250
#  Clusterizando bloco  164
# 250
#  Clusterizando bloco  165
# 250
#  Clusterizando bloco  166
# 250
#  Clusterizando bloco  167
# 250
#  Clusterizando bloco  168
# 250
#  Clusterizando bloco  169
# 250
#  Clusterizando bloco  170
# 250
#  Clusterizando bloco  171
# 250
#  Clusterizando bloco  172
# 250
#  Clusterizando bloco  173
# 250
#  Clusterizando bloco  174
# 250
#  Clusterizando bloco  175
# 250
#  Clusterizando bloco  176
# 250
#  Clusterizando bloco  177
# 250
#  Clusterizando bloco  178
# 250
#  Clusterizando bloco  179
# 250
#  Clusterizando bloco  180
# 250
#  Clusterizando bloco  181
# 250
#  Clusterizando bloco  182
# 250
#  Clusterizando bloco  183
# 250
#  Clusterizando bloco  184
# 250
#  Clusterizando bloco  185
# 250
#  Clusterizando bloco  186
# 250
#  Clusterizando bloco  187
# 250
#  Clusterizando bloco  188
# 250
#  Clusterizando bloco  189
# 250
#  Clusterizando bloco  190
# 250
#  Clusterizando bloco  191
# 250
#  Clusterizando bloco  192
# 250
#  Clusterizando bloco  193
# 250
#  Clusterizando bloco  194
# 250
#  Clusterizando bloco  195
# 250
#  Clusterizando bloco  196
# 250
#  Clusterizando bloco  197
# 250
#  Clusterizando bloco  198
# 250
#  Clusterizando bloco  199
# 250
#  Clusterizando bloco  200
# 250
#  Clusterizando bloco  201
# 250
#  Clusterizando bloco  202
# 250
#  Clusterizando bloco  203
# 250
#  Clusterizando bloco  204
# 250
#  Clusterizando bloco  205
# 250
#  Clusterizando bloco  206
# 250
#  Clusterizando bloco  207
# 250
#  Clusterizando bloco  208
# 250
#  Clusterizando bloco  209
# 250
#  Clusterizando bloco  210
# 250
#  Clusterizando bloco  211
# 250
#  Clusterizando bloco  212
# 250
#  Clusterizando bloco  213
# 250
#  Clusterizando bloco  214
# 250
#  Clusterizando bloco  215
# 250
#  Clusterizando bloco  216
# 250
#  Clusterizando bloco  217
# 250
#  Clusterizando bloco  218
# 250
#  Clusterizando bloco  219
# 250
#  Clusterizando bloco  220
# 250
#  Clusterizando bloco  221
# 250
#  Clusterizando bloco  222
# 250
#  Clusterizando bloco  223
# 250
#  Clusterizando bloco  224
# 250
#  Clusterizando bloco  225
# 250
#  Clusterizando bloco  226
# 250
#  Clusterizando bloco  227
# 250
#  Clusterizando bloco  228
# 250
#  Clusterizando bloco  229
# 250
#  Clusterizando bloco  230
# 250
#  Clusterizando bloco  231
# 250
#  Clusterizando bloco  232
# 250
#  Clusterizando bloco  233
# 250
#  Clusterizando bloco  234
# 250
#  Clusterizando bloco  235
# 250
#  Clusterizando bloco  236
# 250
#  Clusterizando bloco  237
# 250
#  Clusterizando bloco  238
# 250
#  Clusterizando bloco  239
# 250
#  Clusterizando bloco  240
# 250
#  Clusterizando bloco  241
# 250
#  Clusterizando bloco  242
# 250
#  Clusterizando bloco  243
# 250
#  Clusterizando bloco  244
# 250
#  Clusterizando bloco  245
# 250
#  Clusterizando bloco  246
# 250
#  Clusterizando bloco  247
# 250
#  Clusterizando bloco  248
# 250
#  Clusterizando bloco  249
# 250
#  Clusterizando bloco  250
# 250
#  Clusterizando bloco  251
# 250
#  Clusterizando bloco  252
# 250
#  Clusterizando bloco  253
# 250
#  Clusterizando bloco  254
# 250
#  Clusterizando bloco  255
# 250
#  Clusterizando bloco  256
# 250
#  Clusterizando bloco  257
# 250
#  Clusterizando bloco  258
# 250
#  Clusterizando bloco  259
# 250
#  Clusterizando bloco  260
# 250
#  Clusterizando bloco  261
# 250
#  Clusterizando bloco  262
# 250
#  Clusterizando bloco  263
# 250
#  Clusterizando bloco  264
# 250
#  Clusterizando bloco  265
# 250
#  Clusterizando bloco  266
# 250
#  Clusterizando bloco  267
# 250
#  Clusterizando bloco  268
# 250
#  Clusterizando bloco  269
# 250
#  Clusterizando bloco  270
# 250
#  Clusterizando bloco  271
# 250
#  Clusterizando bloco  272
# 250
#  Clusterizando bloco  273
# 250
#  Clusterizando bloco  274
# 250
#  Clusterizando bloco  275
# 250
#  Clusterizando bloco  276
# 250
#  Clusterizando bloco  277
# 250
#  Clusterizando bloco  278
# 250
#  Clusterizando bloco  279
# 250
#  Clusterizando bloco  280
# 250
#  Clusterizando bloco  281
# 250
#  Clusterizando bloco  282
# 250
#  Clusterizando bloco  283
# 250
#  Clusterizando bloco  284
# 250
#  Clusterizando bloco  285
# 250
#  Clusterizando bloco  286
# 250
#  Clusterizando bloco  287
# 250
#  Clusterizando bloco  288
# 250
#  Clusterizando bloco  289
# 250
#  Clusterizando bloco  290
# 250
#  Clusterizando bloco  291
# 250
#  Clusterizando bloco  292
# 250
#  Clusterizando bloco  293
# 250
#  Clusterizando bloco  294
# 250
#  Clusterizando bloco  295
# 250
#  Clusterizando bloco  296
# 250
#  Clusterizando bloco  297
# 250
#  Clusterizando bloco  298
# 250
#  Clusterizando bloco  299
# 250
#  Clusterizando bloco  300
# 250
#  Clusterizando bloco  301
# 250
#  Clusterizando bloco  302
# 250
#  Clusterizando bloco  303
# 250
#  Clusterizando bloco  304
# 250
#  Clusterizando bloco  305
# 250
#  Clusterizando bloco  306
# 250
#  Clusterizando bloco  307
# 250
#  Clusterizando bloco  308
# 250
#  Clusterizando bloco  309
# 250
#  Clusterizando bloco  310
# 250
#  Clusterizando bloco  311
# 250
#  Clusterizando bloco  312
# 250
#  Clusterizando bloco  313
# 250
#  Clusterizando bloco  314
# 250
#  Clusterizando bloco  315
# 250
#  Clusterizando bloco  316
# 250
#  Clusterizando bloco  317
# 250
#  Clusterizando bloco  318
# 250
#  Clusterizando bloco  319
# 250
#  Clusterizando bloco  320
# 250
#  Clusterizando bloco  321
# 250
#  Clusterizando bloco  322
# 250
#  Clusterizando bloco  323
# 250
#  Clusterizando bloco  324
# 250
#  Clusterizando bloco  325
# 250
#  Clusterizando bloco  326
# 250
#  Clusterizando bloco  327
# 250
#  Clusterizando bloco  328
# 250
#  Clusterizando bloco  329
# 250
#  Clusterizando bloco  330
# 250
#  Clusterizando bloco  331
# 250
#  Clusterizando bloco  332
# 250
#  Clusterizando bloco  333
# 250
#  Clusterizando bloco  334
# 250
#  Clusterizando bloco  335
# 250
#  Clusterizando bloco  336
# 250
#  Clusterizando bloco  337
# 250
#  Clusterizando bloco  338
# 250
#  Clusterizando bloco  339
# 250
#  Clusterizando bloco  340
# 250
#  Clusterizando bloco  341
# 250
#  Clusterizando bloco  342
# 250
#  Clusterizando bloco  343
# 250
#  Clusterizando bloco  344
# 250
#  Clusterizando bloco  345
# 250
#  Clusterizando bloco  346
# 250
#  Clusterizando bloco  347
# 250
#  Clusterizando bloco  348
# 250
#  Clusterizando bloco  349
# 250
#  Clusterizando bloco  350
# 250
#  Clusterizando bloco  351
# 250
#  Clusterizando bloco  352
# 250
#  Clusterizando bloco  353
# 250
#  Clusterizando bloco  354
# 250
#  Clusterizando bloco  355
# 250
#  Clusterizando bloco  356
# 250
#  Clusterizando bloco  357
# 250
#  Clusterizando bloco  358
# 250
#  Clusterizando bloco  359
# 250
#  Clusterizando bloco  360
# 250
#  Clusterizando bloco  361
# 250
#  Clusterizando bloco  362
# 250
#  Clusterizando bloco  363
# 250
#  Clusterizando bloco  364
# 250
#  Clusterizando bloco  365
# 250
#  Clusterizando bloco  366
# 250
#  Clusterizando bloco  367
# 250
#  Clusterizando bloco  368
# 250
#  Clusterizando bloco  369
# 250
#  Clusterizando bloco  370
# 250
#  Clusterizando bloco  371
# 250
#  Clusterizando bloco  372
# 250
#  Clusterizando bloco  373
# 250
#  Clusterizando bloco  374
# 250
#  Clusterizando bloco  375
# 250
#  Clusterizando bloco  376
# 250
#  Clusterizando bloco  377
# 250
#  Clusterizando bloco  378
# 250
#  Clusterizando bloco  379
# 250
#  Clusterizando bloco  380
# 250
#  Clusterizando bloco  381
# 250
#  Clusterizando bloco  382
# 250
#  Clusterizando bloco  383
# 250
#  Clusterizando bloco  384
# 250
#  Clusterizando bloco  385
# 250
#  Clusterizando bloco  386
# 250
#  Clusterizando bloco  387
# 250
#  Clusterizando bloco  388
# 250
#  Clusterizando bloco  389
# 250
#  Clusterizando bloco  390
# 250
#  Clusterizando bloco  391
# 250
#  Clusterizando bloco  392
# 250
#  Clusterizando bloco  393
# 250
#  Clusterizando bloco  394
# 250
#  Clusterizando bloco  395
# 250
#  Clusterizando bloco  396
# 250
#  Clusterizando bloco  397
# 250
#  Clusterizando bloco  398
# 250
#  Clusterizando bloco  399
# 250
#  Clusterizando bloco  400
# 250
#  Clusterizando bloco  401
# 250
#  Clusterizando bloco  402
# 250
#  Clusterizando bloco  403
# 250
#  Clusterizando bloco  404
# 250
#  Clusterizando bloco  405
# 250
#  Clusterizando bloco  406
# 250
#  Clusterizando bloco  407
# 250
#  Clusterizando bloco  408
# 250
#  Clusterizando bloco  409
# 250
#  Clusterizando bloco  410
# 250
#  Clusterizando bloco  411
# 250
#  Clusterizando bloco  412
# 250
#  Clusterizando bloco  413
# 250
#  Clusterizando bloco  414
# 250
#  Clusterizando bloco  415
# 250
#  Clusterizando bloco  416
# 250
#  Clusterizando bloco  417
# 250
#  Clusterizando bloco  418
# 250
#  Clusterizando bloco  419
# 250
#  Clusterizando bloco  420
# 250
#  Clusterizando bloco  421
# 250
#  Clusterizando bloco  422
# 250
#  Clusterizando bloco  423
# 250
#  Clusterizando bloco  424
# 250
#  Clusterizando bloco  425
# 250
#  Clusterizando bloco  426
# 250
#  Clusterizando bloco  427
# 250
#  Clusterizando bloco  428
# 250
#  Clusterizando bloco  429
# 250
#  Clusterizando bloco  430
# 250
#  Clusterizando bloco  431
# 250
#  Clusterizando bloco  432
# 250
#  Clusterizando bloco  433
# 250
#  Clusterizando bloco  434
# 250
#  Clusterizando bloco  435
# 250
#  Clusterizando bloco  436
# 250
#  Clusterizando bloco  437
# 250
#  Clusterizando bloco  438
# 250
#  Clusterizando bloco  439
# 250
#  Clusterizando bloco  440
# 250
#  Clusterizando bloco  441
# 250
#  Clusterizando bloco  442
# 250
#  Clusterizando bloco  443
# 250
#  Clusterizando bloco  444
# 250
#  Clusterizando bloco  445
# 250
#  Clusterizando bloco  446
# 250
#  Clusterizando bloco  447
# 250
#  Clusterizando bloco  448
# 250
#  Clusterizando bloco  449
# 250
#  Clusterizando bloco  450
# 250
#  Clusterizando bloco  451
# 250
#  Clusterizando bloco  452
# 250
#  Clusterizando bloco  453
# 250
#  Clusterizando bloco  454
# 250
#  Clusterizando bloco  455
# 250
#  Clusterizando bloco  456
# 250
#  Clusterizando bloco  457
# 250
#  Clusterizando bloco  458
# 250
#  Clusterizando bloco  459
# 250
#  Clusterizando bloco  460
# 250
#  Clusterizando bloco  461
# 250
#  Clusterizando bloco  462
# 250
#  Clusterizando bloco  463
# 250
#  Clusterizando bloco  464
# 250
#  Clusterizando bloco  465
# 250
#  Clusterizando bloco  466
# 250
#  Clusterizando bloco  467
# 250
#  Clusterizando bloco  468
# 250
#  Clusterizando bloco  469
# 250
#  Clusterizando bloco  470
# 250
#  Clusterizando bloco  471
# 250
#  Clusterizando bloco  472
# 250
#  Clusterizando bloco  473
# 250
#  Clusterizando bloco  474
# 250
#  Clusterizando bloco  475
# 250
#  Clusterizando bloco  476
# 250
#  Clusterizando bloco  477
# 250
#  Clusterizando bloco  478
# 250
#  Clusterizando bloco  479
# 250
#  Clusterizando bloco  480
# 250
#  Clusterizando bloco  481
# 250
#  Clusterizando bloco  482
# 250
#  Clusterizando bloco  483
# 250
#  Clusterizando bloco  484
# 250
#  Clusterizando bloco  485
# 250
#  Clusterizando bloco  486
# 250
#  Clusterizando bloco  487
# 250
#  Clusterizando bloco  488
# 250
#  Clusterizando bloco  489
# 250
#  Clusterizando bloco  490
# 250
#  Clusterizando bloco  491
# 250
#  Clusterizando bloco  492
# 250
#  Clusterizando bloco  493
# 250
#  Clusterizando bloco  494
# 250
#  Clusterizando bloco  495
# 250
#  Clusterizando bloco  496
# 250
#  Clusterizando bloco  497
# 250
#  Clusterizando bloco  498
# 250
#  Clusterizando bloco  499
# 250
#  Clusterizando bloco  500
# 250
#  Clusterizando bloco  501
# 250
#  Clusterizando bloco  502
# 250
#  Clusterizando bloco  503
# 250
#  Clusterizando bloco  504
# 250
#  Clusterizando bloco  505
# 250
#  Clusterizando bloco  506
# 250
#  Clusterizando bloco  507
# 250
#  Clusterizando bloco  508
# 250
#  Clusterizando bloco  509
# 250
#  Clusterizando bloco  510
# 250
#  Clusterizando bloco  511
# 250
#  Clusterizando bloco  512
# 250
#  Clusterizando bloco  513
# 250
#  Clusterizando bloco  514
# 250
#  Clusterizando bloco  515
# 250
#  Clusterizando bloco  516
# 250
#  Clusterizando bloco  517
# 250
#  Clusterizando bloco  518
# 250
#  Clusterizando bloco  519
# 250
#  Clusterizando bloco  520
# 250
#  Clusterizando bloco  521
# 250
#  Clusterizando bloco  522
# 250
#  Clusterizando bloco  523
# 250
#  Clusterizando bloco  524
# 250
#  Clusterizando bloco  525
# 250
#  Clusterizando bloco  526
# 250
#  Clusterizando bloco  527
# 250
#  Clusterizando bloco  528
# 250
#  Clusterizando bloco  529
# 250
#  Clusterizando bloco  530
# 250
#  Clusterizando bloco  531
# 250
#  Clusterizando bloco  532
# 250
#  Clusterizando bloco  533
# 250
#  Clusterizando bloco  534
# 250
#  Clusterizando bloco  535
# 250
#  Clusterizando bloco  536
# 250
#  Clusterizando bloco  537
# 250
#  Clusterizando bloco  538
# 250
#  Clusterizando bloco  539
# 250
#  Clusterizando bloco  540
# 250
#  Clusterizando bloco  541
# 250
#  Clusterizando bloco  542
# 250
#  Clusterizando bloco  543
# 250
#  Clusterizando bloco  544
# 250
#  Clusterizando bloco  545
# 250
#  Clusterizando bloco  546
# 250
#  Clusterizando bloco  547
# 250
#  Clusterizando bloco  548
# 250
#  Clusterizando bloco  549
# 250
#  Clusterizando bloco  550
# 250
#  Clusterizando bloco  551
# 250
#  Clusterizando bloco  552
# 250
#  Clusterizando bloco  553
# 250
#  Clusterizando bloco  554
# 250
#  Clusterizando bloco  555
# 250
#  Clusterizando bloco  556
# 250
#  Clusterizando bloco  557
# 250
#  Clusterizando bloco  558
# 250
#  Clusterizando bloco  559
# 250
#  Clusterizando bloco  560
# 250
#  Clusterizando bloco  561
# 250
#  Clusterizando bloco  562
# 250
#  Clusterizando bloco  563
# 250
#  Clusterizando bloco  564
# 250
#  Clusterizando bloco  565
# 250
#  Clusterizando bloco  566
# 250
#  Clusterizando bloco  567
# 250
#  Clusterizando bloco  568
# 250
#  Clusterizando bloco  569
# 250
#  Clusterizando bloco  570
# 250
#  Clusterizando bloco  571
# 250
#  Clusterizando bloco  572
# 250
#  Clusterizando bloco  573
# 250
#  Clusterizando bloco  574
# 250
#  Clusterizando bloco  575
# 250
#  Clusterizando bloco  576
# 250
#  Clusterizando bloco  577
# 250
#  Clusterizando bloco  578
# 250
#  Clusterizando bloco  579
# 250
#  Clusterizando bloco  580
# 250
#  Clusterizando bloco  581
# 250
#  Clusterizando bloco  582
# 250
#  Clusterizando bloco  583
# 250
#  Clusterizando bloco  584
# 250
#  Clusterizando bloco  585
# 250
#  Clusterizando bloco  586
# 250
#  Clusterizando bloco  587
# 250
#  Clusterizando bloco  588
# 250
#  Clusterizando bloco  589
# 250
#  Clusterizando bloco  590
# 250
#  Clusterizando bloco  591
# 250
#  Clusterizando bloco  592
# 250
#  Clusterizando bloco  593
# 250
#  Clusterizando bloco  594
# 250
#  Clusterizando bloco  595
# 250
#  Clusterizando bloco  596
# 250
#  Clusterizando bloco  597
# 250
#  Clusterizando bloco  598
# 250
#  Clusterizando bloco  599
# 250
#  Clusterizando bloco  600
# 250
#  Clusterizando bloco  601
# 250
#  Clusterizando bloco  602
# 250
#  Clusterizando bloco  603
# 250
#  Clusterizando bloco  604
# 250
#  Clusterizando bloco  605
# 250
#  Clusterizando bloco  606
# 250
#  Clusterizando bloco  607
# 250
#  Clusterizando bloco  608
# 250
#  Clusterizando bloco  609
# 250
#  Clusterizando bloco  610
# 250
#  Clusterizando bloco  611
# 250
#  Clusterizando bloco  612
# 250
#  Clusterizando bloco  613
# 250
#  Clusterizando bloco  614
# 250
#  Clusterizando bloco  615
# 250
#  Clusterizando bloco  616
# 250
#  Clusterizando bloco  617
# 250
#  Clusterizando bloco  618
# 250
#  Clusterizando bloco  619
# 250
#  Clusterizando bloco  620
# 250
#  Clusterizando bloco  621
# 250
#  Clusterizando bloco  622
# 250
#  Clusterizando bloco  623
# 250
#  Clusterizando bloco  624
# 250
#  Clusterizando bloco  625
# 250
#  Clusterizando bloco  626
# 250
#  Clusterizando bloco  627
# 250
#  Clusterizando bloco  628
# 250
#  Clusterizando bloco  629
# 250
#  Clusterizando bloco  630
# 250
#  Clusterizando bloco  631
# 250
#  Clusterizando bloco  632
# 250
#  Clusterizando bloco  633
# 250
#  Clusterizando bloco  634
# 250
#  Clusterizando bloco  635
# 250
#  Clusterizando bloco  636
# 250
#  Clusterizando bloco  637
# 250
#  Clusterizando bloco  638
# 250
#  Clusterizando bloco  639
# 250
#  Clusterizando bloco  640
# 250
#  Clusterizando bloco  641
# 250
#  Clusterizando bloco  642
# 250
#  Clusterizando bloco  643
# 250
#  Clusterizando bloco  644
# 250
#  Clusterizando bloco  645
# 250
#  Clusterizando bloco  646
# 250
#  Clusterizando bloco  647
# 250
#  Clusterizando bloco  648
# 250
#  Clusterizando bloco  649
# 250
#  Clusterizando bloco  650
# 250
#  Clusterizando bloco  651
# 250
#  Clusterizando bloco  652
# 250
#  Clusterizando bloco  653
# 250
#  Clusterizando bloco  654
# 250
#  Clusterizando bloco  655
# 250
#  Clusterizando bloco  656
# 250
#  Clusterizando bloco  657
# 250
#  Clusterizando bloco  658
# 250
#  Clusterizando bloco  659
# 250
#  Clusterizando bloco  660
# 250
#  Clusterizando bloco  661
# 250
#  Clusterizando bloco  662
# 250
#  Clusterizando bloco  663
# 250
#  Clusterizando bloco  664
# 250
#  Clusterizando bloco  665
# 250
#  Clusterizando bloco  666
# 250
#  Clusterizando bloco  667
# 250
#  Clusterizando bloco  668
# 250
#  Clusterizando bloco  669
# 250
#  Clusterizando bloco  670
# 250
#  Clusterizando bloco  671
# 250
#  Clusterizando bloco  672
# 250
#  Clusterizando bloco  673
# 250
#  Clusterizando bloco  674
# 250
#  Clusterizando bloco  675
# 250
#  Clusterizando bloco  676
# 250
#  Clusterizando bloco  677
# 250
#  Clusterizando bloco  678
# 250
#  Clusterizando bloco  679
# 250
#  Clusterizando bloco  680
# 250
#  Clusterizando bloco  681
# 250
#  Clusterizando bloco  682
# 250
#  Clusterizando bloco  683
# 250
#  Clusterizando bloco  684
# 250
#  Clusterizando bloco  685
# 250
#  Clusterizando bloco  686
# 250
#  Clusterizando bloco  687
# 250
#  Clusterizando bloco  688
# 250
#  Clusterizando bloco  689
# 250
#  Clusterizando bloco  690
# 250
#  Clusterizando bloco  691
# 250
#  Clusterizando bloco  692
# 250
#  Clusterizando bloco  693
# 250
#  Clusterizando bloco  694
# 250
#  Clusterizando bloco  695
# 250
#  Clusterizando bloco  696
# 250
#  Clusterizando bloco  697
# 250
#  Clusterizando bloco  698
# 250
#  Clusterizando bloco  699
# 250
#  Clusterizando bloco  700
# 250
#  Clusterizando bloco  701
# 250
#  Clusterizando bloco  702
# 250
#  Clusterizando bloco  703
# 250
#  Clusterizando bloco  704
# 250
#  Clusterizando bloco  705
# 250
#  Clusterizando bloco  706
# 250
#  Clusterizando bloco  707
# 250
#  Clusterizando bloco  708
# 250
#  Clusterizando bloco  709
# 250
#  Clusterizando bloco  710
# 250
#  Clusterizando bloco  711
# 250
#  Clusterizando bloco  712
# 250
#  Clusterizando bloco  713
# 250
#  Clusterizando bloco  714
# 250
#  Clusterizando bloco  715
# 250
#  Clusterizando bloco  716
# 250
#  Clusterizando bloco  717
# 250
#  Clusterizando bloco  718
# 250
#  Clusterizando bloco  719
# 250
#  Clusterizando bloco  720
# 250
#  Clusterizando bloco  721
# 250
#  Clusterizando bloco  722
# 250
#  Clusterizando bloco  723
# 250
#  Clusterizando bloco  724
# 250
#  Clusterizando bloco  725
# 250
#  Clusterizando bloco  726
# 250
#  Clusterizando bloco  727
# 250
#  Clusterizando bloco  728
# 250
#  Clusterizando bloco  729
# 250
#  Clusterizando bloco  730
# 250
#  Clusterizando bloco  731
# 250
#  Clusterizando bloco  732
# 250
#  Clusterizando bloco  733
# 250
#  Clusterizando bloco  734
# 250
#  Clusterizando bloco  735
# 250
#  Clusterizando bloco  736
# 250
#  Clusterizando bloco  737
# 250
#  Clusterizando bloco  738
# 250
#  Clusterizando bloco  739
# 250
#  Clusterizando bloco  740
# 250
#  Clusterizando bloco  741
# 250
#  Clusterizando bloco  742
# 250
#  Clusterizando bloco  743
# 250
#  Clusterizando bloco  744
# 250
#  Clusterizando bloco  745
# 250
#  Clusterizando bloco  746
# 250
#  Clusterizando bloco  747
# 250
#  Clusterizando bloco  748
# 250
#  Clusterizando bloco  749
# 250
#  Clusterizando bloco  750
# 250
#  Clusterizando bloco  751
# 250
#  Clusterizando bloco  752
# 250
#  Clusterizando bloco  753
# 250
#  Clusterizando bloco  754
# 250
#  Clusterizando bloco  755
# 250
#  Clusterizando bloco  756
# 250
#  Clusterizando bloco  757
# 250
#  Clusterizando bloco  758
# 250
#  Clusterizando bloco  759
# 250
#  Clusterizando bloco  760
# 250
#  Clusterizando bloco  761
# 250
#  Clusterizando bloco  762
# 250
#  Clusterizando bloco  763
# 250
#  Clusterizando bloco  764
# 250
#  Clusterizando bloco  765
# 250
#  Clusterizando bloco  766
# 250
#  Clusterizando bloco  767
# 250
#  Clusterizando bloco  768
# 250
#  Clusterizando bloco  769
# 250
#  Clusterizando bloco  770
# 250
#  Clusterizando bloco  771
# 250
#  Clusterizando bloco  772
# 250
#  Clusterizando bloco  773
# 250
#  Clusterizando bloco  774
# 250
#  >> Tempo de execução da clusterização na base:  2843.744728565216 s
# --AVALIAÇÃO--
#   BLOCO 0 (teve 150 clusters): Precisão em relação ao bloco: 99.66666666666667 %. -- Precisão em relação a base: 48.84444444444448 %
#
#   BLOCO 1 (teve 151 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 56.51214128035321 %
#
#   BLOCO 2 (teve 136 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 48.676470588235325 %
#
#   BLOCO 3 (teve 153 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 46.44880174291943 %
#
#   BLOCO 4 (teve 160 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 54.500000000000014 %
#
#   BLOCO 5 (teve 150 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 48.53333333333336 %
#
#   BLOCO 6 (teve 149 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.1342281879195 %
#
#   BLOCO 7 (teve 173 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 50.366088631984596 %
#
#   BLOCO 8 (teve 155 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 53.81720430107529 %
#
#   BLOCO 9 (teve 156 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 49.19871794871797 %
#
#   BLOCO 10 (teve 159 clusters): Precisão em relação ao bloco: 99.37106918238993 %. -- Precisão em relação a base: 48.7316561844864 %
#
#   BLOCO 11 (teve 172 clusters): Precisão em relação ao bloco: 98.35271317829456 %. -- Precisão em relação a base: 75.18410852713177 %
#
#   BLOCO 12 (teve 170 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 76.83333333333334 %
#
#   BLOCO 13 (teve 179 clusters): Precisão em relação ao bloco: 98.88268156424581 %. -- Precisão em relação a base: 77.9050279329609 %
#
#   BLOCO 14 (teve 183 clusters): Precisão em relação ao bloco: 98.36065573770492 %. -- Precisão em relação a base: 75.655737704918 %
#
#   BLOCO 15 (teve 185 clusters): Precisão em relação ao bloco: 97.65765765765767 %. -- Precisão em relação a base: 65.43243243243244 %
#
#   BLOCO 16 (teve 169 clusters): Precisão em relação ao bloco: 97.8303747534517 %. -- Precisão em relação a base: 69.78303747534518 %
#
#   BLOCO 17 (teve 175 clusters): Precisão em relação ao bloco: 98.85714285714286 %. -- Precisão em relação a base: 82.1142857142857 %
#
#   BLOCO 18 (teve 166 clusters): Precisão em relação ao bloco: 98.19277108433735 %. -- Precisão em relação a base: 72.35943775100402 %
#
#   BLOCO 19 (teve 179 clusters): Precisão em relação ao bloco: 97.48603351955308 %. -- Precisão em relação a base: 70.92178770949722 %
#
#   BLOCO 20 (teve 206 clusters): Precisão em relação ao bloco: 99.02912621359224 %. -- Precisão em relação a base: 59.84627831715211 %
#
#   BLOCO 21 (teve 202 clusters): Precisão em relação ao bloco: 99.83498349834983 %. -- Precisão em relação a base: 65.56930693069306 %
#
#   BLOCO 22 (teve 161 clusters): Precisão em relação ao bloco: 97.30848861283646 %. -- Precisão em relação a base: 78.26086956521742 %
#
#   BLOCO 23 (teve 175 clusters): Precisão em relação ao bloco: 99.80952380952381 %. -- Precisão em relação a base: 74.75238095238095 %
#
#   BLOCO 24 (teve 173 clusters): Precisão em relação ao bloco: 97.6878612716763 %. -- Precisão em relação a base: 79.44123314065511 %
#
#   BLOCO 25 (teve 152 clusters): Precisão em relação ao bloco: 97.36842105263158 %. -- Precisão em relação a base: 83.31140350877195 %
#
#   BLOCO 26 (teve 157 clusters): Precisão em relação ao bloco: 96.81528662420382 %. -- Precisão em relação a base: 78.2484076433121 %
#
#   BLOCO 27 (teve 165 clusters): Precisão em relação ao bloco: 98.48484848484848 %. -- Precisão em relação a base: 73.94949494949495 %
#
#   BLOCO 28 (teve 163 clusters): Precisão em relação ao bloco: 97.23926380368098 %. -- Precisão em relação a base: 78.57873210633947 %
#
#   BLOCO 29 (teve 184 clusters): Precisão em relação ao bloco: 98.91304347826086 %. -- Precisão em relação a base: 68.64130434782606 %
#
#   BLOCO 30 (teve 151 clusters): Precisão em relação ao bloco: 99.83443708609272 %. -- Precisão em relação a base: 84.75717439293598 %
#
#   BLOCO 31 (teve 162 clusters): Precisão em relação ao bloco: 96.29629629629629 %. -- Precisão em relação a base: 80.73045267489711 %
#
#   BLOCO 32 (teve 166 clusters): Precisão em relação ao bloco: 97.99196787148594 %. -- Precisão em relação a base: 82.89156626506023 %
#
#   BLOCO 33 (teve 140 clusters): Precisão em relação ao bloco: 92.85714285714286 %. -- Precisão em relação a base: 76.23809523809521 %
#
#   BLOCO 34 (teve 168 clusters): Precisão em relação ao bloco: 97.71825396825398 %. -- Precisão em relação a base: 77.57936507936505 %
#
#   BLOCO 35 (teve 171 clusters): Precisão em relação ao bloco: 96.49122807017544 %. -- Precisão em relação a base: 79.9805068226121 %
#
#   BLOCO 36 (teve 157 clusters): Precisão em relação ao bloco: 98.51380042462844 %. -- Precisão em relação a base: 78.35456475583864 %
#
#   BLOCO 37 (teve 157 clusters): Precisão em relação ao bloco: 98.08917197452229 %. -- Precisão em relação a base: 78.84288747346072 %
#
#   BLOCO 38 (teve 174 clusters): Precisão em relação ao bloco: 96.55172413793103 %. -- Precisão em relação a base: 76.25478927203066 %
#
#   BLOCO 39 (teve 166 clusters): Precisão em relação ao bloco: 98.79518072289156 %. -- Precisão em relação a base: 81.58634538152613 %
#
#   BLOCO 40 (teve 149 clusters): Precisão em relação ao bloco: 98.65771812080537 %. -- Precisão em relação a base: 82.77404921700223 %
#
#   BLOCO 41 (teve 157 clusters): Precisão em relação ao bloco: 96.81528662420382 %. -- Precisão em relação a base: 73.69426751592356 %
#
#   BLOCO 42 (teve 162 clusters): Precisão em relação ao bloco: 94.9074074074074 %. -- Precisão em relação a base: 78.3641975308642 %
#
#   BLOCO 43 (teve 183 clusters): Precisão em relação ao bloco: 98.08743169398907 %. -- Precisão em relação a base: 71.77595628415297 %
#
#   BLOCO 44 (teve 164 clusters): Precisão em relação ao bloco: 98.17073170731707 %. -- Precisão em relação a base: 75.36585365853657 %
#
#   BLOCO 45 (teve 200 clusters): Precisão em relação ao bloco: 97.33333333333334 %. -- Precisão em relação a base: 61.88333333333333 %
#
#   BLOCO 46 (teve 171 clusters): Precisão em relação ao bloco: 97.07602339181285 %. -- Precisão em relação a base: 76.32553606237819 %
#
#   BLOCO 47 (teve 160 clusters): Precisão em relação ao bloco: 95.9375 %. -- Precisão em relação a base: 73.77083333333331 %
#
#   BLOCO 48 (teve 104 clusters): Precisão em relação ao bloco: 96.15384615384616 %. -- Precisão em relação a base: 80.3205128205128 %
#
#   BLOCO 49 (teve 147 clusters): Precisão em relação ao bloco: 97.56235827664398 %. -- Precisão em relação a base: 76.859410430839 %
#
#   BLOCO 50 (teve 204 clusters): Precisão em relação ao bloco: 99.26470588235294 %. -- Precisão em relação a base: 63.12908496732027 %
#
#   BLOCO 51 (teve 200 clusters): Precisão em relação ao bloco: 99.0 %. -- Precisão em relação a base: 69.45000000000002 %
#
#   BLOCO 52 (teve 191 clusters): Precisão em relação ao bloco: 98.56020942408377 %. -- Precisão em relação a base: 72.40837696335076 %
#
#   BLOCO 53 (teve 169 clusters): Precisão em relação ao bloco: 98.81656804733728 %. -- Precisão em relação a base: 72.61341222879686 %
#
#   BLOCO 54 (teve 175 clusters): Precisão em relação ao bloco: 99.80952380952382 %. -- Precisão em relação a base: 76.02857142857142 %
#
#   BLOCO 55 (teve 157 clusters): Precisão em relação ao bloco: 98.19532908704885 %. -- Precisão em relação a base: 83.1528662420382 %
#
#   BLOCO 56 (teve 155 clusters): Precisão em relação ao bloco: 98.22580645161291 %. -- Precisão em relação a base: 77.66666666666666 %
#
#   BLOCO 57 (teve 175 clusters): Precisão em relação ao bloco: 98.85714285714286 %. -- Precisão em relação a base: 70.92380952380954 %
#
#   BLOCO 58 (teve 163 clusters): Precisão em relação ao bloco: 98.77300613496932 %. -- Precisão em relação a base: 74.39672801635993 %
#
#   BLOCO 59 (teve 188 clusters): Precisão em relação ao bloco: 98.93617021276596 %. -- Precisão em relação a base: 66.29432624113475 %
#
#   BLOCO 60 (teve 176 clusters): Precisão em relação ao bloco: 98.86363636363636 %. -- Precisão em relação a base: 68.4090909090909 %
#
#   BLOCO 61 (teve 154 clusters): Precisão em relação ao bloco: 97.40259740259741 %. -- Precisão em relação a base: 76.08225108225106 %
#
#   BLOCO 62 (teve 171 clusters): Precisão em relação ao bloco: 98.24561403508771 %. -- Precisão em relação a base: 70.7699805068226 %
#
#   BLOCO 63 (teve 191 clusters): Precisão em relação ao bloco: 98.95287958115183 %. -- Precisão em relação a base: 63.29842931937173 %
#
#   BLOCO 64 (teve 187 clusters): Precisão em relação ao bloco: 98.93048128342245 %. -- Precisão em relação a base: 67.54901960784315 %
#
#   BLOCO 65 (teve 171 clusters): Precisão em relação ao bloco: 98.24561403508771 %. -- Precisão em relação a base: 72.31968810916182 %
#
#   BLOCO 66 (teve 164 clusters): Precisão em relação ao bloco: 98.47560975609755 %. -- Precisão em relação a base: 71.73780487804879 %
#
#   BLOCO 67 (teve 183 clusters): Precisão em relação ao bloco: 98.36065573770492 %. -- Precisão em relação a base: 71.4389799635701 %
#
#   BLOCO 68 (teve 194 clusters): Precisão em relação ao bloco: 96.90721649484536 %. -- Precisão em relação a base: 63.754295532646054 %
#
#   BLOCO 69 (teve 155 clusters): Precisão em relação ao bloco: 96.7741935483871 %. -- Precisão em relação a base: 78.29032258064512 %
#
#   BLOCO 70 (teve 176 clusters): Precisão em relação ao bloco: 97.1590909090909 %. -- Precisão em relação a base: 68.94886363636364 %
#
#   BLOCO 71 (teve 192 clusters): Precisão em relação ao bloco: 98.4375 %. -- Precisão em relação a base: 70.12152777777777 %
#
#   BLOCO 72 (teve 199 clusters): Precisão em relação ao bloco: 98.99497487437185 %. -- Precisão em relação a base: 67.50418760469013 %
#
#   BLOCO 73 (teve 170 clusters): Precisão em relação ao bloco: 97.6470588235294 %. -- Precisão em relação a base: 74.31372549019609 %
#
#   BLOCO 74 (teve 178 clusters): Precisão em relação ao bloco: 96.91011235955057 %. -- Precisão em relação a base: 67.52808988764045 %
#
#   BLOCO 75 (teve 157 clusters): Precisão em relação ao bloco: 99.04458598726114 %. -- Precisão em relação a base: 75.9447983014862 %
#
#   BLOCO 76 (teve 180 clusters): Precisão em relação ao bloco: 95.83333333333334 %. -- Precisão em relação a base: 65.52777777777776 %
#
#   BLOCO 77 (teve 174 clusters): Precisão em relação ao bloco: 97.70114942528735 %. -- Precisão em relação a base: 70.47892720306514 %
#
#   BLOCO 78 (teve 165 clusters): Precisão em relação ao bloco: 99.39393939393939 %. -- Precisão em relação a base: 79.73737373737374 %
#
#   BLOCO 79 (teve 174 clusters): Precisão em relação ao bloco: 98.27586206896551 %. -- Precisão em relação a base: 76.72413793103449 %
#
#   BLOCO 80 (teve 162 clusters): Precisão em relação ao bloco: 96.91358024691358 %. -- Precisão em relação a base: 75.45267489711934 %
#
#   BLOCO 81 (teve 164 clusters): Precisão em relação ao bloco: 99.6951219512195 %. -- Precisão em relação a base: 76.36178861788619 %
#
#   BLOCO 82 (teve 175 clusters): Precisão em relação ao bloco: 97.71428571428571 %. -- Precisão em relação a base: 75.94285714285714 %
#
#   BLOCO 83 (teve 163 clusters): Precisão em relação ao bloco: 97.85276073619632 %. -- Precisão em relação a base: 77.02453987730061 %
#
#   BLOCO 84 (teve 177 clusters): Precisão em relação ao bloco: 99.71751412429379 %. -- Precisão em relação a base: 71.81732580037665 %
#
#   BLOCO 85 (teve 167 clusters): Precisão em relação ao bloco: 97.60479041916167 %. -- Precisão em relação a base: 77.29540918163671 %
#
#   BLOCO 86 (teve 170 clusters): Precisão em relação ao bloco: 97.94117647058823 %. -- Precisão em relação a base: 73.0686274509804 %
#
#   BLOCO 87 (teve 178 clusters): Precisão em relação ao bloco: 96.06741573033707 %. -- Precisão em relação a base: 70.7677902621723 %
#
#   BLOCO 88 (teve 182 clusters): Precisão em relação ao bloco: 98.35164835164835 %. -- Precisão em relação a base: 69.7802197802198 %
#
#   BLOCO 89 (teve 202 clusters): Precisão em relação ao bloco: 99.25742574257426 %. -- Precisão em relação a base: 57.08745874587458 %
#
#   BLOCO 90 (teve 204 clusters): Precisão em relação ao bloco: 98.2843137254902 %. -- Precisão em relação a base: 66.49509803921572 %
#
#   BLOCO 91 (teve 168 clusters): Precisão em relação ao bloco: 98.66071428571429 %. -- Precisão em relação a base: 79.96031746031746 %
#
#   BLOCO 92 (teve 166 clusters): Precisão em relação ao bloco: 96.23493975903614 %. -- Precisão em relação a base: 74.89959839357431 %
#
#   BLOCO 93 (teve 173 clusters): Precisão em relação ao bloco: 99.42196531791907 %. -- Precisão em relação a base: 79.69171483622351 %
#
#   BLOCO 94 (teve 166 clusters): Precisão em relação ao bloco: 96.6867469879518 %. -- Precisão em relação a base: 76.44578313253012 %
#
#   BLOCO 95 (teve 158 clusters): Precisão em relação ao bloco: 97.25738396624472 %. -- Precisão em relação a base: 67.62658227848101 %
#
#   BLOCO 96 (teve 203 clusters): Precisão em relação ao bloco: 99.50738916256158 %. -- Precisão em relação a base: 64.39244663382595 %
#
#   BLOCO 97 (teve 177 clusters): Precisão em relação ao bloco: 94.63276836158192 %. -- Precisão em relação a base: 74.51035781544255 %
#
#   BLOCO 98 (teve 172 clusters): Precisão em relação ao bloco: 97.67441860465115 %. -- Precisão em relação a base: 76.89922480620154 %
#
#   BLOCO 99 (teve 157 clusters): Precisão em relação ao bloco: 99.20382165605095 %. -- Precisão em relação a base: 76.48619957537154 %
#
#   BLOCO 100 (teve 164 clusters): Precisão em relação ao bloco: 99.39024390243902 %. -- Precisão em relação a base: 75.91463414634147 %
#
#   BLOCO 101 (teve 175 clusters): Precisão em relação ao bloco: 97.14285714285714 %. -- Precisão em relação a base: 69.44761904761906 %
#
#   BLOCO 102 (teve 165 clusters): Precisão em relação ao bloco: 96.76767676767676 %. -- Precisão em relação a base: 75.17171717171716 %
#
#   BLOCO 103 (teve 161 clusters): Precisão em relação ao bloco: 98.29192546583852 %. -- Precisão em relação a base: 80.351966873706 %
#
#   BLOCO 104 (teve 165 clusters): Precisão em relação ao bloco: 95.15151515151516 %. -- Precisão em relação a base: 75.92929292929293 %
#
#   BLOCO 105 (teve 185 clusters): Precisão em relação ao bloco: 99.45945945945947 %. -- Precisão em relação a base: 67.68468468468468 %
#
#   BLOCO 106 (teve 182 clusters): Precisão em relação ao bloco: 97.8021978021978 %. -- Precisão em relação a base: 67.61904761904762 %
#
#   BLOCO 107 (teve 175 clusters): Precisão em relação ao bloco: 95.85714285714285 %. -- Precisão em relação a base: 70.65714285714289 %
#
#   BLOCO 108 (teve 194 clusters): Precisão em relação ao bloco: 98.19587628865979 %. -- Precisão em relação a base: 56.40034364261166 %
#
#   BLOCO 109 (teve 164 clusters): Precisão em relação ao bloco: 96.34146341463415 %. -- Precisão em relação a base: 77.4288617886179 %
#
#   BLOCO 110 (teve 164 clusters): Precisão em relação ao bloco: 96.34146341463415 %. -- Precisão em relação a base: 76.29065040650406 %
#
#   BLOCO 111 (teve 169 clusters): Precisão em relação ao bloco: 98.22485207100591 %. -- Precisão em relação a base: 75.02958579881656 %
#
#   BLOCO 112 (teve 157 clusters): Precisão em relação ao bloco: 95.54140127388536 %. -- Precisão em relação a base: 74.81953290870487 %
#
#   BLOCO 113 (teve 176 clusters): Precisão em relação ao bloco: 96.44886363636364 %. -- Precisão em relação a base: 71.61931818181819 %
#
#   BLOCO 114 (teve 160 clusters): Precisão em relação ao bloco: 98.75 %. -- Precisão em relação a base: 82.1875 %
#
#   BLOCO 115 (teve 175 clusters): Precisão em relação ao bloco: 98.38095238095238 %. -- Precisão em relação a base: 75.53333333333332 %
#
#   BLOCO 116 (teve 176 clusters): Precisão em relação ao bloco: 98.1534090909091 %. -- Precisão em relação a base: 73.7215909090909 %
#
#   BLOCO 117 (teve 158 clusters): Precisão em relação ao bloco: 97.46835443037975 %. -- Precisão em relação a base: 79.70464135021099 %
#
#   BLOCO 118 (teve 172 clusters): Precisão em relação ao bloco: 99.4186046511628 %. -- Precisão em relação a base: 78.10077519379844 %
#
#   BLOCO 119 (teve 176 clusters): Precisão em relação ao bloco: 98.1534090909091 %. -- Precisão em relação a base: 71.5909090909091 %
#
#   BLOCO 120 (teve 153 clusters): Precisão em relação ao bloco: 96.73202614379085 %. -- Precisão em relação a base: 77.21132897603485 %
#
#   BLOCO 121 (teve 161 clusters): Precisão em relação ao bloco: 95.03105590062113 %. -- Precisão em relação a base: 71.15942028985508 %
#
#   BLOCO 122 (teve 179 clusters): Precisão em relação ao bloco: 95.81005586592178 %. -- Precisão em relação a base: 75.51210428305399 %
#
#   BLOCO 123 (teve 167 clusters): Precisão em relação ao bloco: 97.90419161676647 %. -- Precisão em relação a base: 72.54491017964072 %
#
#   BLOCO 124 (teve 169 clusters): Precisão em relação ao bloco: 98.81656804733728 %. -- Precisão em relação a base: 79.62524654832347 %
#
#   BLOCO 125 (teve 156 clusters): Precisão em relação ao bloco: 98.5042735042735 %. -- Precisão em relação a base: 82.36111111111111 %
#
#   BLOCO 126 (teve 158 clusters): Precisão em relação ao bloco: 96.83544303797468 %. -- Precisão em relação a base: 75.5801687763713 %
#
#   BLOCO 127 (teve 166 clusters): Precisão em relação ao bloco: 96.98795180722891 %. -- Precisão em relação a base: 72.90160642570282 %
#
#   BLOCO 128 (teve 186 clusters): Precisão em relação ao bloco: 98.38709677419355 %. -- Precisão em relação a base: 70.53763440860217 %
#
#   BLOCO 129 (teve 198 clusters): Precisão em relação ao bloco: 98.86363636363636 %. -- Precisão em relação a base: 61.94444444444442 %
#
#   BLOCO 130 (teve 188 clusters): Precisão em relação ao bloco: 99.46808510638297 %. -- Precisão em relação a base: 68.95390070921984 %
#
#   BLOCO 131 (teve 187 clusters): Precisão em relação ao bloco: 99.46524064171123 %. -- Precisão em relação a base: 64.24242424242424 %
#
#   BLOCO 132 (teve 168 clusters): Precisão em relação ao bloco: 97.61904761904762 %. -- Precisão em relação a base: 79.94047619047619 %
#
#   BLOCO 133 (teve 160 clusters): Precisão em relação ao bloco: 97.96875 %. -- Precisão em relação a base: 82.07291666666666 %
#
#   BLOCO 134 (teve 193 clusters): Precisão em relação ao bloco: 97.23661485319516 %. -- Precisão em relação a base: 65.64766839378238 %
#
#   BLOCO 135 (teve 180 clusters): Precisão em relação ao bloco: 99.44444444444444 %. -- Precisão em relação a base: 69.93518518518518 %
#
#   BLOCO 136 (teve 176 clusters): Precisão em relação ao bloco: 98.29545454545455 %. -- Precisão em relação a base: 73.05871212121214 %
#
#   BLOCO 137 (teve 167 clusters): Precisão em relação ao bloco: 96.10778443113772 %. -- Precisão em relação a base: 72.34530938123751 %
#
#   BLOCO 138 (teve 184 clusters): Precisão em relação ao bloco: 98.36956521739131 %. -- Precisão em relação a base: 70.85144927536231 %
#
#   BLOCO 139 (teve 169 clusters): Precisão em relação ao bloco: 98.07692307692307 %. -- Precisão em relação a base: 68.698224852071 %
#
#   BLOCO 140 (teve 212 clusters): Precisão em relação ao bloco: 99.52830188679245 %. -- Precisão em relação a base: 59.38679245283019 %
#
#   BLOCO 141 (teve 198 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 67.89562289562286 %
#
#   BLOCO 142 (teve 168 clusters): Precisão em relação ao bloco: 98.80952380952381 %. -- Precisão em relação a base: 75.00992063492063 %
#
#   BLOCO 143 (teve 172 clusters): Precisão em relação ao bloco: 96.80232558139535 %. -- Precisão em relação a base: 76.56976744186046 %
#
#   BLOCO 144 (teve 169 clusters): Precisão em relação ao bloco: 96.44970414201184 %. -- Precisão em relação a base: 73.50098619329388 %
#
#   BLOCO 145 (teve 176 clusters): Precisão em relação ao bloco: 97.44318181818183 %. -- Precisão em relação a base: 72.03598484848486 %
#
#   BLOCO 146 (teve 172 clusters): Precisão em relação ao bloco: 99.12790697674419 %. -- Precisão em relação a base: 74.54457364341084 %
#
#   BLOCO 147 (teve 173 clusters): Precisão em relação ao bloco: 97.6878612716763 %. -- Precisão em relação a base: 74.41233140655108 %
#
#   BLOCO 148 (teve 161 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 77.56728778467907 %
#
#   BLOCO 149 (teve 194 clusters): Precisão em relação ao bloco: 98.02405498281787 %. -- Precisão em relação a base: 70.16323024054984 %
#
#   BLOCO 150 (teve 165 clusters): Precisão em relação ao bloco: 97.87878787878788 %. -- Precisão em relação a base: 73.84848484848487 %
#
#   BLOCO 151 (teve 220 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 58.31818181818183 %
#
#   BLOCO 152 (teve 196 clusters): Precisão em relação ao bloco: 99.23469387755102 %. -- Precisão em relação a base: 56.30952380952381 %
#
#   BLOCO 153 (teve 202 clusters): Precisão em relação ao bloco: 99.00990099009901 %. -- Precisão em relação a base: 62.937293729372925 %
#
#   BLOCO 154 (teve 199 clusters): Precisão em relação ao bloco: 98.49246231155779 %. -- Precisão em relação a base: 67.57956448911222 %
#
#   BLOCO 155 (teve 192 clusters): Precisão em relação ao bloco: 98.4375 %. -- Precisão em relação a base: 68.22048611111109 %
#
#   BLOCO 156 (teve 190 clusters): Precisão em relação ao bloco: 98.42105263157895 %. -- Precisão em relação a base: 64.14912280701756 %
#
#   BLOCO 157 (teve 191 clusters): Precisão em relação ao bloco: 97.90575916230367 %. -- Precisão em relação a base: 63.35951134380454 %
#
#   BLOCO 158 (teve 228 clusters): Precisão em relação ao bloco: 99.56140350877193 %. -- Precisão em relação a base: 52.64619883040936 %
#
#   BLOCO 159 (teve 163 clusters): Precisão em relação ao bloco: 97.54601226993866 %. -- Precisão em relação a base: 71.97341513292433 %
#
#   BLOCO 160 (teve 161 clusters): Precisão em relação ao bloco: 98.13664596273291 %. -- Precisão em relação a base: 76.20082815734992 %
#
#   BLOCO 161 (teve 192 clusters): Precisão em relação ao bloco: 96.35416666666666 %. -- Precisão em relação a base: 68.49826388888886 %
#
#   BLOCO 162 (teve 218 clusters): Precisão em relação ao bloco: 99.31192660550458 %. -- Precisão em relação a base: 61.79663608562691 %
#
#   BLOCO 163 (teve 161 clusters): Precisão em relação ao bloco: 97.51552795031056 %. -- Precisão em relação a base: 78.39544513457557 %
#
#   BLOCO 164 (teve 187 clusters): Precisão em relação ao bloco: 99.46524064171123 %. -- Precisão em relação a base: 56.56862745098042 %
#
#   BLOCO 165 (teve 159 clusters): Precisão em relação ao bloco: 98.74213836477988 %. -- Precisão em relação a base: 78.38574423480085 %
#
#   BLOCO 166 (teve 225 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 53.67407407407405 %
#
#   BLOCO 167 (teve 205 clusters): Precisão em relação ao bloco: 99.51219512195122 %. -- Precisão em relação a base: 59.43902439024391 %
#
#   BLOCO 168 (teve 200 clusters): Precisão em relação ao bloco: 99.5 %. -- Precisão em relação a base: 66.23333333333336 %
#
#   BLOCO 169 (teve 199 clusters): Precisão em relação ao bloco: 98.24120603015075 %. -- Precisão em relação a base: 60.804020100502484 %
#
#   BLOCO 170 (teve 221 clusters): Precisão em relação ao bloco: 99.5475113122172 %. -- Precisão em relação a base: 58.14479638009048 %
#
#   BLOCO 171 (teve 206 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 67.96925566343043 %
#
#   BLOCO 172 (teve 198 clusters): Precisão em relação ao bloco: 98.48484848484848 %. -- Precisão em relação a base: 62.71043771043773 %
#
#   BLOCO 173 (teve 170 clusters): Precisão em relação ao bloco: 97.6470588235294 %. -- Precisão em relação a base: 79.421568627451 %
#
#   BLOCO 174 (teve 172 clusters): Precisão em relação ao bloco: 98.11046511627907 %. -- Precisão em relação a base: 71.5988372093023 %
#
#   BLOCO 175 (teve 186 clusters): Precisão em relação ao bloco: 97.93906810035843 %. -- Precisão em relação a base: 71.836917562724 %
#
#   BLOCO 176 (teve 192 clusters): Precisão em relação ao bloco: 97.13541666666666 %. -- Precisão em relação a base: 67.81250000000001 %
#
#   BLOCO 177 (teve 204 clusters): Precisão em relação ao bloco: 98.77450980392157 %. -- Precisão em relação a base: 63.594771241830074 %
#
#   BLOCO 178 (teve 176 clusters): Precisão em relação ao bloco: 95.17045454545455 %. -- Precisão em relação a base: 68.4185606060606 %
#
#   BLOCO 179 (teve 150 clusters): Precisão em relação ao bloco: 97.0 %. -- Precisão em relação a base: 78.15555555555555 %
#
#   BLOCO 180 (teve 159 clusters): Precisão em relação ao bloco: 96.85534591194968 %. -- Precisão em relação a base: 73.82599580712788 %
#
#   BLOCO 181 (teve 206 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 61.94174757281553 %
#
#   BLOCO 182 (teve 180 clusters): Precisão em relação ao bloco: 97.77777777777777 %. -- Precisão em relação a base: 71.8425925925926 %
#
#   BLOCO 183 (teve 199 clusters): Precisão em relação ao bloco: 97.48743718592965 %. -- Precisão em relação a base: 63.35845896147404 %
#
# ...
#
#   BLOCO 662 (teve 160 clusters): Precisão em relação ao bloco: 96.87500000000003 %. -- Precisão em relação a base: 81.19791666666664 %
#
#   BLOCO 663 (teve 172 clusters): Precisão em relação ao bloco: 95.93023255813954 %. -- Precisão em relação a base: 72.94573643410853 %
#
#   BLOCO 664 (teve 164 clusters): Precisão em relação ao bloco: 98.78048780487805 %. -- Precisão em relação a base: 81.36178861788618 %
#
#   BLOCO 665 (teve 198 clusters): Precisão em relação ao bloco: 97.97979797979798 %. -- Precisão em relação a base: 70.05892255892256 %
#
#   BLOCO 666 (teve 176 clusters): Precisão em relação ao bloco: 98.86363636363636 %. -- Precisão em relação a base: 73.50378787878786 %
#
#   BLOCO 667 (teve 181 clusters): Precisão em relação ao bloco: 96.68508287292818 %. -- Precisão em relação a base: 69.50276243093924 %
#
#   BLOCO 668 (teve 195 clusters): Precisão em relação ao bloco: 98.46153846153847 %. -- Precisão em relação a base: 62.2905982905983 %
#
#   BLOCO 669 (teve 188 clusters): Precisão em relação ao bloco: 98.93617021276597 %. -- Precisão em relação a base: 63.0141843971631 %
#
#   BLOCO 670 (teve 188 clusters): Precisão em relação ao bloco: 99.46808510638297 %. -- Precisão em relação a base: 67.6418439716312 %
#
#   BLOCO 671 (teve 188 clusters): Precisão em relação ao bloco: 99.46808510638297 %. -- Precisão em relação a base: 66.9503546099291 %
#
#   BLOCO 672 (teve 174 clusters): Precisão em relação ao bloco: 99.13793103448276 %. -- Precisão em relação a base: 69.98084291187739 %
#
#   BLOCO 673 (teve 190 clusters): Precisão em relação ao bloco: 98.42105263157895 %. -- Precisão em relação a base: 69.3157894736842 %
#
#   BLOCO 674 (teve 170 clusters): Precisão em relação ao bloco: 97.05882352941177 %. -- Precisão em relação a base: 77.2352941176471 %
#
#   BLOCO 675 (teve 168 clusters): Precisão em relação ao bloco: 97.47023809523809 %. -- Precisão em relação a base: 71.67658730158729 %
#
#   BLOCO 676 (teve 166 clusters): Precisão em relação ao bloco: 99.19678714859437 %. -- Precisão em relação a base: 74.69879518072293 %
#
#   BLOCO 677 (teve 148 clusters): Precisão em relação ao bloco: 98.3108108108108 %. -- Precisão em relação a base: 79.98873873873875 %
#
#   BLOCO 678 (teve 167 clusters): Precisão em relação ao bloco: 97.90419161676647 %. -- Precisão em relação a base: 77.3053892215569 %
#
#   BLOCO 679 (teve 158 clusters): Precisão em relação ao bloco: 98.20675105485233 %. -- Precisão em relação a base: 84.35654008438819 %
#
#   BLOCO 680 (teve 160 clusters): Precisão em relação ao bloco: 97.29166666666667 %. -- Precisão em relação a base: 76.86458333333334 %
#
#   BLOCO 681 (teve 184 clusters): Precisão em relação ao bloco: 98.91304347826086 %. -- Precisão em relação a base: 75.03623188405797 %
#
#   BLOCO 682 (teve 198 clusters): Precisão em relação ao bloco: 98.48484848484848 %. -- Precisão em relação a base: 74.14141414141415 %
#
#   BLOCO 683 (teve 185 clusters): Precisão em relação ao bloco: 99.27927927927928 %. -- Precisão em relação a base: 69.94594594594594 %
#
#   BLOCO 684 (teve 161 clusters): Precisão em relação ao bloco: 98.75776397515527 %. -- Precisão em relação a base: 76.57349896480329 %
#
#   BLOCO 685 (teve 167 clusters): Precisão em relação ao bloco: 98.20359281437125 %. -- Precisão em relação a base: 73.03393213572853 %
#
#   BLOCO 686 (teve 159 clusters): Precisão em relação ao bloco: 99.37106918238993 %. -- Precisão em relação a base: 77.01257861635219 %
#
#   BLOCO 687 (teve 167 clusters): Precisão em relação ao bloco: 96.20758483033931 %. -- Precisão em relação a base: 74.18163672654691 %
#
#   BLOCO 688 (teve 168 clusters): Precisão em relação ao bloco: 97.91666666666666 %. -- Precisão em relação a base: 78.33333333333333 %
#
#   BLOCO 689 (teve 162 clusters): Precisão em relação ao bloco: 95.67901234567901 %. -- Precisão em relação a base: 79.35185185185183 %
#
#   BLOCO 690 (teve 161 clusters): Precisão em relação ao bloco: 96.58385093167702 %. -- Precisão em relação a base: 74.71014492753625 %
#
#   BLOCO 691 (teve 161 clusters): Precisão em relação ao bloco: 97.30848861283643 %. -- Precisão em relação a base: 74.32712215320909 %
#
#   BLOCO 692 (teve 178 clusters): Precisão em relação ao bloco: 98.59550561797754 %. -- Precisão em relação a base: 81.66666666666666 %
#
#   BLOCO 693 (teve 177 clusters): Precisão em relação ao bloco: 97.74011299435028 %. -- Precisão em relação a base: 71.08286252354048 %
#
#   BLOCO 694 (teve 149 clusters): Precisão em relação ao bloco: 97.98657718120806 %. -- Precisão em relação a base: 81.35346756152124 %
#
#   BLOCO 695 (teve 167 clusters): Precisão em relação ao bloco: 97.0059880239521 %. -- Precisão em relação a base: 78.97205588822354 %
#
#   BLOCO 696 (teve 175 clusters): Precisão em relação ao bloco: 98.19047619047619 %. -- Precisão em relação a base: 75.37142857142858 %
#
#   BLOCO 697 (teve 170 clusters): Precisão em relação ao bloco: 98.23529411764706 %. -- Precisão em relação a base: 73.55882352941177 %
#
#   BLOCO 698 (teve 166 clusters): Precisão em relação ao bloco: 99.4979919678715 %. -- Precisão em relação a base: 70.02008032128515 %
#
#   BLOCO 699 (teve 169 clusters): Precisão em relação ao bloco: 96.44970414201184 %. -- Precisão em relação a base: 73.84615384615387 %
#
#   BLOCO 700 (teve 164 clusters): Precisão em relação ao bloco: 97.5609756097561 %. -- Precisão em relação a base: 73.89227642276423 %
#
#   BLOCO 701 (teve 173 clusters): Precisão em relação ao bloco: 98.84393063583815 %. -- Precisão em relação a base: 73.5645472061657 %
#
#   BLOCO 702 (teve 155 clusters): Precisão em relação ao bloco: 96.7741935483871 %. -- Precisão em relação a base: 76.72043010752691 %
#
#   BLOCO 703 (teve 167 clusters): Precisão em relação ao bloco: 99.10179640718563 %. -- Precisão em relação a base: 78.78243512974052 %
#
#   BLOCO 704 (teve 165 clusters): Precisão em relação ao bloco: 96.96969696969697 %. -- Precisão em relação a base: 71.24242424242425 %
#
#   BLOCO 705 (teve 169 clusters): Precisão em relação ao bloco: 98.22485207100591 %. -- Precisão em relação a base: 71.77514792899409 %
#
#   BLOCO 706 (teve 166 clusters): Precisão em relação ao bloco: 97.28915662650603 %. -- Precisão em relação a base: 78.01204819277109 %
#
#   BLOCO 707 (teve 174 clusters): Precisão em relação ao bloco: 98.85057471264368 %. -- Precisão em relação a base: 73.87931034482762 %
#
#   BLOCO 708 (teve 153 clusters): Precisão em relação ao bloco: 98.69281045751634 %. -- Precisão em relação a base: 80.11982570806099 %
#
#   BLOCO 709 (teve 164 clusters): Precisão em relação ao bloco: 97.10365853658537 %. -- Precisão em relação a base: 73.37398373983739 %
#
#   BLOCO 710 (teve 161 clusters): Precisão em relação ao bloco: 97.20496894409938 %. -- Precisão em relação a base: 81.46997929606627 %
#
#   BLOCO 711 (teve 169 clusters): Precisão em relação ao bloco: 95.56213017751479 %. -- Precisão em relação a base: 76.05522682445758 %
#
#   BLOCO 712 (teve 179 clusters): Precisão em relação ao bloco: 96.64804469273743 %. -- Precisão em relação a base: 76.57355679702044 %
#
#   BLOCO 713 (teve 160 clusters): Precisão em relação ao bloco: 98.75 %. -- Precisão em relação a base: 76.13541666666667 %
#
#   BLOCO 714 (teve 171 clusters): Precisão em relação ao bloco: 99.41520467836257 %. -- Precisão em relação a base: 78.06042884990254 %
#
#   BLOCO 715 (teve 165 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 78.23232323232322 %
#
#   BLOCO 716 (teve 153 clusters): Precisão em relação ao bloco: 97.82135076252723 %. -- Precisão em relação a base: 75.05446623093681 %
#
#   BLOCO 717 (teve 171 clusters): Precisão em relação ao bloco: 95.6140350877193 %. -- Precisão em relação a base: 77.50487329434698 %
#
#   BLOCO 718 (teve 173 clusters): Precisão em relação ao bloco: 97.6878612716763 %. -- Precisão em relação a base: 73.03468208092487 %
#
#   BLOCO 719 (teve 174 clusters): Precisão em relação ao bloco: 98.85057471264368 %. -- Precisão em relação a base: 69.94252873563218 %
#
#   BLOCO 720 (teve 167 clusters): Precisão em relação ao bloco: 93.7125748502994 %. -- Precisão em relação a base: 75.11976047904191 %
#
#   BLOCO 721 (teve 164 clusters): Precisão em relação ao bloco: 98.47560975609755 %. -- Precisão em relação a base: 75.90447154471543 %
#
#   BLOCO 722 (teve 196 clusters): Precisão em relação ao bloco: 98.9795918367347 %. -- Precisão em relação a base: 67.71258503401361 %
#
#   BLOCO 723 (teve 171 clusters): Precisão em relação ao bloco: 98.83040935672514 %. -- Precisão em relação a base: 78.80116959064327 %
#
#   BLOCO 724 (teve 171 clusters): Precisão em relação ao bloco: 98.83040935672514 %. -- Precisão em relação a base: 73.99610136452243 %
#
#   BLOCO 725 (teve 204 clusters): Precisão em relação ao bloco: 99.34640522875819 %. -- Precisão em relação a base: 63.35784313725493 %
#
#   BLOCO 726 (teve 183 clusters): Precisão em relação ao bloco: 97.81420765027322 %. -- Precisão em relação a base: 66.60291438979962 %
#
#   BLOCO 727 (teve 160 clusters): Precisão em relação ao bloco: 97.1875 %. -- Precisão em relação a base: 75.09374999999999 %
#
#   BLOCO 728 (teve 163 clusters): Precisão em relação ao bloco: 99.18200408997956 %. -- Precisão em relação a base: 69.23312883435582 %
#
#   BLOCO 729 (teve 127 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 60.695538057742795 %
#
#   BLOCO 730 (teve 193 clusters): Precisão em relação ao bloco: 99.48186528497409 %. -- Precisão em relação a base: 54.51640759930918 %
#
#   BLOCO 731 (teve 171 clusters): Precisão em relação ao bloco: 97.953216374269 %. -- Precisão em relação a base: 73.07992202729046 %
#
#   BLOCO 732 (teve 175 clusters): Precisão em relação ao bloco: 99.14285714285714 %. -- Precisão em relação a base: 71.03809523809524 %
#
#   BLOCO 733 (teve 157 clusters): Precisão em relação ao bloco: 96.92144373673035 %. -- Precisão em relação a base: 66.42250530785563 %
#
#   BLOCO 734 (teve 181 clusters): Precisão em relação ao bloco: 98.89502762430939 %. -- Precisão em relação a base: 69.91712707182319 %
#
#   BLOCO 735 (teve 161 clusters): Precisão em relação ao bloco: 99.68944099378882 %. -- Precisão em relação a base: 76.66666666666667 %
#
#   BLOCO 736 (teve 182 clusters): Precisão em relação ao bloco: 98.35164835164835 %. -- Precisão em relação a base: 70.15567765567766 %
#
#   BLOCO 737 (teve 181 clusters): Precisão em relação ao bloco: 98.89502762430939 %. -- Precisão em relação a base: 75.83793738489874 %
#
#   BLOCO 738 (teve 162 clusters): Precisão em relação ao bloco: 98.55967078189302 %. -- Precisão em relação a base: 81.08024691358025 %
#
#   BLOCO 739 (teve 154 clusters): Precisão em relação ao bloco: 98.53896103896103 %. -- Precisão em relação a base: 78.09523809523809 %
#
#   BLOCO 740 (teve 163 clusters): Precisão em relação ao bloco: 97.54601226993866 %. -- Precisão em relação a base: 75.34764826175869 %
#
#   BLOCO 741 (teve 164 clusters): Precisão em relação ao bloco: 97.96747967479676 %. -- Precisão em relação a base: 83.94308943089432 %
#
#   BLOCO 742 (teve 158 clusters): Precisão em relação ao bloco: 96.20253164556962 %. -- Precisão em relação a base: 83.14345991561181 %
#
#   BLOCO 743 (teve 156 clusters): Precisão em relação ao bloco: 98.71794871794873 %. -- Precisão em relação a base: 84.31623931623932 %
#
#   BLOCO 744 (teve 165 clusters): Precisão em relação ao bloco: 96.96969696969697 %. -- Precisão em relação a base: 79.57575757575756 %
#
#   BLOCO 745 (teve 162 clusters): Precisão em relação ao bloco: 97.68518518518519 %. -- Precisão em relação a base: 79.73251028806581 %
#
#   BLOCO 746 (teve 177 clusters): Precisão em relação ao bloco: 98.87005649717514 %. -- Precisão em relação a base: 73.17325800376645 %
#
#   BLOCO 747 (teve 180 clusters): Precisão em relação ao bloco: 98.05555555555556 %. -- Precisão em relação a base: 67.21296296296296 %
#
#   BLOCO 748 (teve 161 clusters): Precisão em relação ao bloco: 97.67080745341616 %. -- Precisão em relação a base: 75.27950310559007 %
#
#   BLOCO 749 (teve 162 clusters): Precisão em relação ao bloco: 97.53086419753086 %. -- Precisão em relação a base: 78.06584362139918 %
#
#   BLOCO 750 (teve 166 clusters): Precisão em relação ao bloco: 97.43975903614458 %. -- Precisão em relação a base: 75.56224899598394 %
#
#   BLOCO 751 (teve 165 clusters): Precisão em relação ao bloco: 98.5858585858586 %. -- Precisão em relação a base: 77.55555555555554 %
#
#   BLOCO 752 (teve 189 clusters): Precisão em relação ao bloco: 100.0 %. -- Precisão em relação a base: 66.7195767195767 %
#
#   BLOCO 753 (teve 172 clusters): Precisão em relação ao bloco: 98.83720930232558 %. -- Precisão em relação a base: 72.93604651162791 %
#
#   BLOCO 754 (teve 162 clusters): Precisão em relação ao bloco: 98.0246913580247 %. -- Precisão em relação a base: 77.21193415637863 %
#
#   BLOCO 755 (teve 169 clusters): Precisão em relação ao bloco: 96.92307692307693 %. -- Precisão em relação a base: 76.34122287968445 %
#
#   BLOCO 756 (teve 163 clusters): Precisão em relação ao bloco: 96.93251533742331 %. -- Precisão em relação a base: 81.86094069529652 %
#
#   BLOCO 757 (teve 157 clusters): Precisão em relação ao bloco: 97.45222929936305 %. -- Precisão em relação a base: 83.05732484076434 %
#
#   BLOCO 758 (teve 150 clusters): Precisão em relação ao bloco: 99.11111111111113 %. -- Precisão em relação a base: 82.68888888888888 %
#
#   BLOCO 759 (teve 159 clusters): Precisão em relação ao bloco: 96.85534591194968 %. -- Precisão em relação a base: 79.62264150943396 %
#
#   BLOCO 760 (teve 151 clusters): Precisão em relação ao bloco: 98.01324503311258 %. -- Precisão em relação a base: 83.38852097130243 %
#
#   BLOCO 761 (teve 155 clusters): Precisão em relação ao bloco: 95.64516129032258 %. -- Precisão em relação a base: 82.44086021505376 %
#
#   BLOCO 762 (teve 168 clusters): Precisão em relação ao bloco: 97.61904761904762 %. -- Precisão em relação a base: 75.94246031746033 %
#
#   BLOCO 763 (teve 156 clusters): Precisão em relação ao bloco: 98.07692307692307 %. -- Precisão em relação a base: 80.68376068376068 %
#
#   BLOCO 764 (teve 169 clusters): Precisão em relação ao bloco: 98.22485207100591 %. -- Precisão em relação a base: 84.51676528599606 %
#
#   BLOCO 765 (teve 169 clusters): Precisão em relação ao bloco: 97.63313609467455 %. -- Precisão em relação a base: 73.27416173570018 %
#
#   BLOCO 766 (teve 172 clusters): Precisão em relação ao bloco: 95.15503875968992 %. -- Precisão em relação a base: 72.77131782945737 %
#
#   BLOCO 767 (teve 174 clusters): Precisão em relação ao bloco: 97.98850574712644 %. -- Precisão em relação a base: 76.25478927203066 %
#
#   BLOCO 768 (teve 206 clusters): Precisão em relação ao bloco: 99.02912621359224 %. -- Precisão em relação a base: 64.60355987055014 %
#
#   BLOCO 769 (teve 169 clusters): Precisão em relação ao bloco: 98.22485207100591 %. -- Precisão em relação a base: 74.33925049309663 %
#
#   BLOCO 770 (teve 165 clusters): Precisão em relação ao bloco: 98.93939393939394 %. -- Precisão em relação a base: 77.06060606060606 %
#
#   BLOCO 771 (teve 165 clusters): Precisão em relação ao bloco: 99.39393939393939 %. -- Precisão em relação a base: 69.9090909090909 %
#
#   BLOCO 772 (teve 177 clusters): Precisão em relação ao bloco: 98.87005649717514 %. -- Precisão em relação a base: 70.15065913370998 %
#
#   BLOCO 773 (teve 187 clusters): Precisão em relação ao bloco: 97.05882352941177 %. -- Precisão em relação a base: 68.14616755793227 %
#
#   BLOCO 774 (teve 176 clusters): Precisão em relação ao bloco: 98.86363636363636 %. -- Precisão em relação a base: 72.25378787878786 %
#
# Relacao Bloco:  97.97851978347941  %
# Relacao Base Toda:  73.4398032454566  %
#
# ------------------------------------------------------------------
#
# Precisão:
#      Relacao Bloco  Relacao Base Toda
# 0        99.666667          48.844444
# 1       100.000000          56.512141
# 2       100.000000          48.676471
# 3       100.000000          46.448802
# 4       100.000000          54.500000
# ..             ...                ...
# 770      98.939394          77.060606
# 771      99.393939          69.909091
# 772      98.870056          70.150659
# 773      97.058824          68.146168
# 774      98.863636          72.253788
#
# [775 rows x 2 columns]
